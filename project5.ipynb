# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('purchases.csv')
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                    Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# Display top 10 rows of dataframe
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6   93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8          2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9  3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
# Display last 10 rows of dataframe
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\r\nWest Danielle, VT 96934...  93 ty       PM
# 9991            PSC 8165, Box 8498\r\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\r\nWallhaven, LA ...  40 vH       PM
# 9993  7555 Larson Locks Suite 229\r\nEllisburgh, MA ...  72 jg       PM
# 9994     6276 Rojas Hollow\r\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# Check data types of each column
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
# Check null values in each column
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
# Check number of rows and columns in the datframe
df.shape
# Out:
# (10000, 14)

# %%
# Show all columns first then find the length of each column
# Set pandas to display all columns
pd.set_option('display.max_columns', None)
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#Show all the dataframe with all the columns
# Set pandas to display all rows
# pd.set_option('display.max_rows', None)
# Set pandas to display 2000 rows (as all rows cause issues in VS Code)
pd.set_option('display.max_rows', 2000)

# %%
# Show all number of rows
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                    Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# Show complete information of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# Show the highest Purchase Price
df['Purchase Price'].max()
# Out:
# 99.99

# %%
# Show the lowest Purchase Price
df['Purchase Price'].min()
# Out:
# 0.0

# %%
# Show the average Purchase Price
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
# Show number of people who has French ('fr') language
df['Language'].value_counts()['fr']
# Out:
# 1097

# %%
# Show all rows that has Job column contains 'engineer'
df[df['Job'].str.contains('engineer')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 50    41159 Michael Centers\r\nAdamsfort, RI 37108-6674  46 Ce       PM
# 103              480 Ronald Cape\r\nJohnville, MA 53644  11 wg       AM
# 193   1010 Mahoney Mills Suite 486\r\nWest Daniellev...  70 Fd       AM
# 200                         USCGC Grant\r\nFPO AA 10424  97 qN       PM
# 202   24079 Kelly Crest Apt. 260\r\nMayerborough, MH...  09 rQ       PM
# 246     666 Davis Junction\r\nEast Destinyton, IL 88122  50 WE       PM
# 270             6015 Mario Isle\r\nPort Jason, IN 20903  78 Ag       PM
# 277       6721 Terry Fort Apt. 660\r\nLeeside, WV 25475  35 tW       PM
# 279        68007 Kristin Field\r\nJohnsonland, GU 67451  77 Qa       PM
# 297      995 David Court\r\nRichardsonchester, NH 80155  32 aP       PM
# ...

# %%
# Show all rows that has Job column contains 'engineer' case insensitive
df[df['Job'].str.contains('engineer', case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 50    41159 Michael Centers\r\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\r\nSandraview, S...  59 LJ       AM
# 60    7126 Katherine Squares\r\nPerkinsview, CO 9729...  63 qu       AM
# 64    937 Weaver Isle Apt. 096\r\nTracyborough, KY 1...  97 QO       AM
# 82    493 Smith Valleys Suite 004\r\nNew Madelinevil...  35 ls       PM
# 92              Unit 9659 Box 0618\r\nDPO AA 00377-5360  37 jN       AM
# 98    192 Malone Stream Suite 756\r\nLake Gary, KS 3...  00 zU       AM
# 103              480 Ronald Cape\r\nJohnville, MA 53644  11 wg       AM
# 155           649 Murphy Estates\r\nWayneland, MS 16599  18 ou       PM
# 173   8071 Ellis Courts Suite 037\r\nNew Katelynvill...  12 VI       PM
# ...

# %%
# Find the length of resulting data
len(df[df['Job'].str.contains('engineer', case=False)])
# Out:
# 984

# %%
# Find email of the person with the IP Address as '132.207.160.22'
df[df['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
# Find number of people who has Mastercard as their Credit Card and made purchase above $50
df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)][['Email','Purchase Price']]
df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)]['Email'].count()
# Out:
# 405

# %%
#Find the email of the person with the following Credit Card: 4664825258997302
df[df['Credit Card'] == 4664825258997302][['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %%
# How many people purchase during AM
# Use count() to count number of records
df[df['AM or PM'] == 'AM']['Email'].count()
# Out:
# 4932

# %%
# How many people purchase during PM
df[df['AM or PM'] == 'PM']['Email'].count()
# Out:
# 5068

# %%
# How many people have a Credit Card that expires in 2020
df[df['CC Exp Date'].str.contains('/20')]['Email'].count()
# Count number of values in CC Exp Date column that contains '/20' which represents year 2020
# Other way to do it is to create user function and iterate with for loop to count number of values
# Out:
# 988

# %%
# What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)

df['Email'].str.split('@').str[1].value_counts().head(5)
# Grab the email column and split it into two columns, one with the username and one with the host. Result is a list of tuples. Take the 2nd element (host) since the first is the username.
# Then, use value_counts() to count the number of times each host was used
# Default sorting order is descending, so we use head(5) to get the top 5
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
